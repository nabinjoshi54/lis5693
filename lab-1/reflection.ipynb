# %% [markdown]
# <a href="https://colab.research.google.com/github/nabinjoshi54/lis5693/blob/main/reflection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The API worked successfully and I was able to retrieve the transcript of youtube video. I saved it as text file. I initially had trouble understanding how to use API key and format. I followed the exact instructons provided and I was able to complete the assignemnt.The instructions were clear and I want to thank professor for this.
